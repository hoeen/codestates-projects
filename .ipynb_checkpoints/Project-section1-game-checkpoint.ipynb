# %% [markdown]
# # AI_08_박우석
#
# # Project - Section 1

# %% [markdown]
# Goal of project
#
# 앞서 알려드린 것 처럼.
#
# **다음 분기에 어떤 게임을 설계해야 할까**
# 를 정하는 과정과 그 결과를 보여주는 것이 목표입니다.
#
# 데이터셋을 읽는 것 부터,
#
# 이러한 게임을 만들어야 한다는 결론까지 의 과정을 colab을 사용하여 작성하고,
#
# 해당 내용을 기반으로 설명하는 영상을 작성하는 것이
#
# 박우석님이 이번 프로젝트 기간 동안 하셔야 하는 일입니다.
#
# 당연히 어떠한 코드, 분석, 라이브러리 혹은 목표를 가지는지는 온전히 박우석님의 자유입니다.
#
# 그러나, Section 1 Project 인 만큼 해당 기간 동안 배운 내용을 위주로 설정하는 것이 권장됩니다.
#
# 아직 배우지 않은 Deep Learning을 사용하면 곤란하겠죠?
#
# 추가로, 박우석님의 발표를 듣는 사람은 비데이터 직군이라 가정합니다.
#
# 즉 박우석님의 생각이나 가정들을 설명하는 과정에서 최대한 배경지식이 없는 사람들도 이해할 수 있도록 노력하셔야 할 겁니다.
#
# #### 발표에 반드시 포함되어야 하는 내용은 다음과 같습니다.
#
# - 지역에 따라서 선호하는 게임 장르가 다를까 라는 질문에 대답을 하셔야합니다.
# - 연도별 게임의 트렌드가 있을까 라는 질문에 대답을 하셔야합니다.
# - 출고량이 높은 게임에 대한 분석 및 시각화 프로세스가 포함되어야 합니다.
#
# 위 3가지 내용과 여러분들의 개인적인 분석 목표, 질문을 더하여 프로젝트를 완성하세요.

# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/datasets/vgames2.csv',
           index_col=0)
data
# Out:
#                                                  Name Platform    Year  \
# 1                        Candace Kane's Candy Factory       DS  2008.0
# 2                                      The Munchables      Wii  2009.0
# 3      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 4                    Deal or No Deal: Special Edition       DS  2010.0
# 5           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16594                         Ice Age 2: The Meltdown       GC  2006.0
# 16595                     Rainbow Islands: Revolution      PSP  2005.0
# 16596                                        NBA 2K16      PS3  2015.0
# 16597                     Toukiden: The Age of Demons      PSV  2013.0
# 16598                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# 1         Action                    Destineer     0.04        0        0
# 2         Action           Namco Bandai Games     0.17        0        0
# 3      Adventure                    Alchemist        0        0     0.02
# 4           Misc                    Zoo Games     0.04        0        0
# 5       Platform                  D3Publisher     0.12     0.09        0
# ...          ...                          ...      ...      ...      ...
# 16594   Platform                Vivendi Games     0.15     0.04        0
# 16595     Action            Rising Star Games     0.01        0        0
# 16596     Sports         Take-Two Interactive     0.44     0.19     0.03
# 16597     Action                   Tecmo Koei     0.05     0.05     0.25
# 16598   Fighting  Sony Computer Entertainment        0        0     0.16
#
#       Other_Sales
# 1               0
# 2            0.01
# 3               0
# 4               0
# 5            0.04
# ...           ...
# 16594        0.01
# 16595           0
# 16596        0.13
# 16597        0.03
# 16598        0.01
#
# [16598 rows x 9 columns]

# %% [markdown]
# Data Description
#
# - Name : 게임의 이름입니다.
# - Platform : 게임이 지원되는 플랫폼의 이름입니다.
# - Year : 게임이 출시된 연도입니다.
# - Genre : 게임의 장르입니다.
# - Publisher : 게임을 제작한 회사입니다.
# - NA_Sales : 북미지역에서의 출고량입니다.
# - EU_Sales : 유럽지역에서의 출고량입니다.
# - JP_Sales : 일본지역에서의 출고량입니다.
# - Other_Sales : 기타지역에서의 출고량입니다.

# %% [markdown]
# 단위 조정
# 1. 기본단위를 M으로 본다.
# 2. K 가 있는 것들은 1000으로 나눠주고 뒤에 M을 붙인다.
#
# 0.3 = 0.3M
#
# 50k = 0.05 = 50,000
#
# (K * 1,000
#  M(기본단위) * 1,000,000)

# %% [markdown]
# ## data 정리. 결측치 조사

# %%
# 결측치
data.isnull().sum()
# Out:
# Name             0
# Platform         0
# Year           271
# Genre           50
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# dtype: int64

# %%
data.loc[data.Year.isnull(),:]
# Out:
#                                               Name Platform  Year       Genre  \
# 32                                       Rock Band     X360   NaN        Misc
# 110     Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN      Racing
# 274    Jewel Link Chronicles: Mountains of Madness       DS   NaN      Puzzle
# 359             Majesty 2: The Fantasy Kingdom Sim     X360   NaN  Simulation
# 431                                     Famista 64      N64   NaN      Sports
# ...                                            ...      ...   ...         ...
# 16241                                Freaky Flyers       GC   NaN      Racing
# 16276                               Space Invaders     2600   NaN     Shooter
# 16279                                Madden NFL 11      Wii   NaN      Sports
# 16426                               Yoostar on MTV     X360   NaN        Misc
# 16433                                  Bejeweled 3     X360   NaN      Puzzle
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 32        Electronic Arts     1.93     0.34        0        0.21
# 110               Unknown        0        0     0.02           0
# 274             Avanquest        0     0.06        0        0.01
# 359               Unknown     0.03        0        0           0
# 431    Namco Bandai Games        0        0     0.17        0.03
# ...                   ...      ...      ...      ...         ...
# 16241             Unknown     0.01        0        0           0
# 16276               Atari     2.36     0.14       0M        0.03
# 16279             Unknown      0.7        0        0         50K
# 16426             Unknown     0.06        0        0           0
# 16433             Unknown     0.13        0        0        0.01
#
# [271 rows x 9 columns]

# %%
data.loc[data.Genre.isnull(),:]
# Out:
#                                               Name Platform    Year Genre  \
# 51                        Ape Escape: On the Loose      PSP  2005.0   NaN
# 409                                    NBA Ballers       XB  2004.0   NaN
# 1329                                    NFL Street       XB  2004.0   NaN
# 1583                SingStar Singalong With Disney      PS2  2008.0   NaN
# 1972                           Pokemon X/Pokemon Y      3DS  2013.0   NaN
# 2044                                 NASCAR Racing       PS  1996.0   NaN
# 2498              Jurassic Park III: Island Attack      GBA  2001.0   NaN
# 3354                   The Godfather: Dons Edition      PS3  2007.0   NaN
# 3364                  Ski-Doo Snowmobile Challenge     X360  2009.0   NaN
# 3471            Batman Beyond: Return of the Joker      N64  2000.0   NaN
# 3516      Princess Saver! Eternal Love for My Lady      PS2  2010.0   NaN
# 3933                             MVP Baseball 2004      PS2  2004.0   NaN
# 4149                           Grand Theft Auto IV       PC  2008.0   NaN
# 4350                     Brain Quest: Grades 5 & 6       DS  2008.0   NaN
# 4546             Dragon Ball Z: Ultimate Tenkaichi     X360  2011.0   NaN
# 4599                                     Wii Party      Wii  2010.0   NaN
# 4936                              Astonishia Story      PSP  2006.0   NaN
# 5669                                  Chrono Cross       PS  1999.0   NaN
# 5714                  Back to the Future: The Game     XOne  2015.0   NaN
# 5946                             Medabots: Metabee      GBA  2002.0   NaN
# 6799                                  UFO: Trilogy       PC  2007.0   NaN
# 7144                  Largo Winch .// Commando Sar       PS  2002.0   NaN
# 7337                                 Madden NFL 11      PS2  2010.0   NaN
# 7527                               Ukiyo no Shishi      PS3  2015.0   NaN
# 7798                     Myth Makers: Orbs of Doom      Wii  2007.0   NaN
# 9489                             Final Fantasy XII      PS2  2006.0   NaN
# 10433        The Mummy: Tomb of the Dragon Emperor      Wii  2008.0   NaN
# 10502                      Bakemonogatari Portable      PSP  2012.0   NaN
# 10875            Karaoke Revolution Glee: Volume 3      Wii  2011.0   NaN
# 11051                                 Puppy Palace       DS  2008.0   NaN
# 11064                                     Yakuza 3      PS3  2009.0   NaN
# 11269            Cloudy With a Chance of Meatballs      PS3  2009.0   NaN
# 11497                                     F-Zero X      N64  1998.0   NaN
# 11669  The History Channel: Battle for the Pacific      Wii  2007.0   NaN
# 11700                               Time Travelers      PSV  2012.0   NaN
# 12315                                   Ice Hockey     2600  1980.0   NaN
# 12332                           Onimusha: Warlords      PS2  2001.0   NaN
# 12341                             Virtual Chess 64      N64  1998.0   NaN
# 12871         PQ2: Practical Intelligence Quotient      PSP  2006.0   NaN
# 12983                                  Urban Chaos       PS  1999.0   NaN
# 13349        Treasure Report: Kikai Jikake no Isan       DS  2011.0   NaN
# 14931                            Skylanders Giants      PS3  2012.0   NaN
# 15078                   Myth Makers: Super Kart GP      Wii  2007.0   NaN
# 15212                    James Bond 007: Nightfire       XB  2002.0   NaN
# 15427            WarioWare, Inc.: Mega Party Game$       GC  2003.0   NaN
# 15527                                   Bloodborne      PS4  2015.0   NaN
# 16092                       Brain Boost: Beta Wave       DS  2005.0   NaN
# 16432            Cars: Mater-National Championship     X360  2007.0   NaN
# 16556                          Apache: Air Assault       PC  2010.0   NaN
# 16588                 Need for Speed Underground 2       XB  2004.0   NaN
#
#                           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 51      Sony Computer Entertainment     0.52     0.01     0.12        0.05
# 409                    Midway Games     0.37     0.11        0        0.02
# 1329                Electronic Arts     0.49     0.15        0        0.02
# 1583    Sony Computer Entertainment        0     0.04        0        0.57
# 1972                       Nintendo    5170K     4.05     4.34        0.79
# 2044                    Pioneer LDC     0.23     0.16        0        0.03
# 2498   Konami Digital Entertainment     0.13     0.05        0           0
# 3354                Electronic Arts     0.25     0.02        0        0.03
# 3364                   Valcon Games     0.03        0        0           0
# 3471                        Ubisoft     0.07     0.02        0           0
# 3516                        Comfort        0        0     0.02           0
# 3933                Electronic Arts      1.1     0.06        0        0.18
# 4149           Take-Two Interactive     0.01     0.79        0        0.08
# 4350                Electronic Arts     0.11        0        0        0.01
# 4546             Namco Bandai Games     0.39      0.1     0.01        0.04
# 4599                       Nintendo     1.79     3.53     2.49        0.68
# 4936                        Ubisoft     0.03        0        0           0
# 5669                     SquareSoft     0.62     0.42     0.69        0.12
# 5714                 Telltale Games        0     0.02        0           0
# 5946                        Natsume     0.04     0.01        0           0
# 6799                        Unknown        0     0.02        0           0
# 7144                        Ubisoft     0.01     0.01        0           0
# 7337                Electronic Arts     0.41     0.02        0        0.07
# 7527             Namco Bandai Games        0        0     0.03           0
# 7798                 Popcorn Arcade     0.05        0        0           0
# 9489                    Square Enix     1.88        0     2.33        1.74
# 10433                 Vivendi Games     0.08        0        0        0.01
# 10502            Namco Bandai Games        0        0     0.05           0
# 10875  Konami Digital Entertainment     0.24     0.04        0        0.02
# 11051                       Ubisoft     0.35        0        0        0.03
# 11064                          Sega     0.21     0.21     0.62        0.08
# 11269                       Ubisoft     0.09     0.01        0        0.01
# 11497                      Nintendo     0.45     0.33     0.29        0.03
# 11669                    Activision      0.1        0        0        0.01
# 11700                       Level 5        0        0     0.05           0
# 12315                    Activision     0.46     0.03        0        0.01
# 12332            Virgin Interactive     0.99     0.48     1.09        0.14
# 12341                         Titus     0.05     0.01        0           0
# 12871                   D3Publisher     0.04        0        0           0
# 12983             Eidos Interactive     0.06     0.04        0        0.01
# 13349            Namco Bandai Games        0        0     0.05           0
# 14931                    Activision     0.35     0.52        0        0.22
# 15078                Popcorn Arcade     0.01        0        0           0
# 15212               Electronic Arts     0.58     220K        0        0.03
# 15427                      Nintendo      0.2     0.05     0.44        0.02
# 15527   Sony Computer Entertainment        1     0.76     0.26        0.36
# 16092                     505 Games     0.14        0        0        0.01
# 16432                           THQ     0.13        0        0        0.01
# 16556                   Just Flight        0     0.03        0        0.01
# 16588               Electronic Arts     1.38      0.8        0         0.1

# %%
data.loc[data.Publisher.isnull(),:]
# Out:
#                                                     Name Platform    Year  \
# 273                                   UK Truck Simulator       PC  2010.0
# 1314      All Grown Up!: Game Boy Advance Video Volume 1      GBA  2004.0
# 1561   Teenage Mutant Ninja Turtles: Game Boy Advance...      GBA  2004.0
# 1790   Nicktoons Collection: Game Boy Advance Video V...      GBA  2004.0
# 1880                      Monster Hunter Frontier Online      PS3     NaN
# 1962   Nicktoons Collection: Game Boy Advance Video V...      GBA  2004.0
# 2071                                      World of Tanks     X360     NaN
# 2971                                Chou Soujuu Mecha MG       DS     NaN
# 3185                        Action Man-Operation Extreme       PS     NaN
# 3413                                   Dance with Devils      PSV  2016.0
# 3534                           B.L.U.E.: Legend of Water       PS     NaN
# 3563                          wwe Smackdown vs. Raw 2006      PS2     NaN
# 3640                     Homeworld Remastered Collection       PC     NaN
# 3685     Dragon Ball GT: Game Boy Advance Video Volume 1      GBA  2004.0
# 4309   Umineko no Naku Koro ni San: Shinjitsu to Gens...      PS3     NaN
# 4368   Strawberry Shortcake: Game Boy Advance Video V...      GBA  2004.0
# 5208   Cartoon Network Collection: Game Boy Advance V...      GBA  2005.0
# 5246   Cartoon Network Collection: Game Boy Advance V...      GBA  2005.0
# 5388   Moshi, Kono Sekai ni Kami-sama ga Iru to suru ...      PSV  2016.0
# 6210              Atsumare! Power Pro Kun no DS Koushien       DS     NaN
# 6393                         Brothers in Arms: Furious 4     X360     NaN
# 7371                                        Stronghold 3       PC  2011.0
# 7985                    Disney Channel Collection Vol. 1      GBA  2004.0
# 8039   Super Robot Monkey Team: Game Boy Advance Vide...      GBA  2005.0
# 8237                                  Bentley's Hackpack      GBA  2005.0
# 8356   Cartoon Network Collection: Game Boy Advance V...      GBA  2004.0
# 8652                                  Sonic the Hedgehog      PS3     NaN
# 8874                     Legends of Oz: Dorothy's Return      3DS  2014.0
# 9129   The Fairly Odd Parents: Game Boy Advance Video...      GBA  2004.0
# 9685       Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii     NaN
# 9878                                        Mario Tennis      3DS     NaN
# 10157  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA     NaN
# 10224                   Demolition Company: Gold Edition       PC  2011.0
# 11310                                     Triple Play 99       PS     NaN
# 11499  Nicktoons Collection: Game Boy Advance Video V...      GBA  2005.0
# 11642             AKB1/48: Idol to Guam de Koishitara...     X360     NaN
# 11677                             Farming Simulator 2011       PC  2010.0
# 12127                                      Silverlicious       DS  2012.0
# 12177  Dora the Explorer: Game Boy Advance Video Volu...      GBA  2004.0
# 12469  The Fairly Odd Parents: Game Boy Advance Video...      GBA  2004.0
# 12561  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2004.0
# 12901  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2004.0
# 13183           Sonic X: Game Boy Advance Video Volume 1      GBA  2004.0
# 13205                                            Xia-Xia       DS  2012.0
# 13451                                Bikkuriman Daijiten       DS     NaN
# 13767                                       Housekeeping       DS     NaN
# 13811  Pokémon: Johto Photo Finish: Game Boy Advance ...      GBA  2004.0
# 13838  Cartoon Network Collection: Game Boy Advance V...      GBA  2004.0
# 13924       Prinny: Can I Really Be The Hero? (US sales)      PSP     NaN
# 14384                   Thomas the Tank Engine & Friends      GBA  2004.0
# 14475                             Driving Simulator 2011       PC  2011.0
# 14829  Codename: Kids Next Door: Game Boy Advance Vid...      GBA  2004.0
# 15152  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2004.0
# 15369       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA  2007.0
# 15670                     Yu Yu Hakusho: Dark Tournament      PS2     NaN
# 15806                                       Dream Dancer       DS     NaN
# 16068                                     Bound By Flame     X360  2014.0
# 16131  Super Robot Wars OG Saga: Masou Kishin II - Re...      PSP     NaN
#
#               Genre Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 273      Simulation       NaN        0     0.03        0           0
# 1314           Misc       NaN     0.17     0.06        0           0
# 1561           Misc       NaN     0.12     0.04        0           0
# 1790           Misc       NaN     0.16     0.06        0           0
# 1880   Role-Playing       NaN        0        0     0.05           0
# 1962           Misc       NaN     0.46     0.17        0        0.01
# 2071        Shooter       NaN        0     0.03        0           0
# 2971     Simulation       NaN        0        0     0.06           0
# 3185         Action       NaN     0.05     0.03        0        0.01
# 3413         Action       NaN        0        0     0.01           0
# 3534      Adventure       NaN        0        0     0.04           0
# 3563       Fighting       NaN     1.57     1.02        0        0.41
# 3640       Strategy       NaN        0     0.01        0           0
# 3685           Misc       NaN     0.12     0.05        0           0
# 4309      Adventure       NaN        0        0     0.02           0
# 4368           Misc       NaN     0.11     0.04        0           0
# 5208           Misc       NaN     0.23     0.08        0        0.01
# 5246           Misc       NaN     0.11     0.04        0           0
# 5388      Adventure       NaN        0        0     0.02           0
# 6210         Sports       NaN        0        0      0.1           0
# 6393        Shooter       NaN     0.01        0        0           0
# 7371       Strategy       NaN     0.06      0.1        0           0
# 7985           Misc       NaN     0.08     0.03        0           0
# 8039           Misc       NaN     0.01        0        0           0
# 8237           Misc       NaN     0.67     0.25        0        0.02
# 8356           Misc       NaN     0.06     0.02        0           0
# 8652       Platform       NaN        0     0.48        0           0
# 8874         Puzzle       NaN        0     0.01        0           0
# 9129           Misc       NaN     0.31     0.11        0        0.01
# 9685         Action       NaN     0.15     0.05     0.14        0.01
# 9878         Sports       NaN        0        0     0.02           0
# 10157        Action       NaN        0        0     0.27        0.01
# 10224    Simulation       NaN        0     0.02        0           0
# 11310        Sports       NaN     0.81     0.55        0         0.1
# 11499          Misc       NaN     0.01     0.01        0           0
# 11642          Misc       NaN        0        0     0.01           0
# 11677    Simulation       NaN        0     0.13        0           0
# 12127        Action       NaN     0.03        0        0           0
# 12177          Misc       NaN     0.18     0.07        0           0
# 12469          Misc       NaN      0.3     0.11        0        0.01
# 12561          Misc       NaN     0.15     0.05        0           0
# 12901          Misc       NaN     0.46     0.17        0        0.01
# 13183          Misc       NaN     0.19     0.07        0           0
# 13205      Platform       NaN        0     0.02        0           0
# 13451          Misc       NaN        0        0     0.03           0
# 13767        Action       NaN        0        0     0.04           0
# 13811          Misc       NaN     0.11     0.04        0           0
# 13838          Misc       NaN     0.18     0.07        0           0
# 13924        Action       NaN     0.06        0        0           0
# 14384     Adventure       NaN     0.13     0.05        0           0
# 14475        Racing       NaN       0M     0.01        0           0
# 14829          Misc       NaN     0.12     0.05        0           0
# 15152          Misc       NaN     0.38     0.14        0        0.01
# 15369          Misc       NaN     0.87     0.32        0        0.02
# 15670      Fighting       NaN      0.1     0.08        0        0.03
# 15806          Misc       NaN     0.01        0        0           0
# 16068  Role-Playing       NaN        0     0.01        0           0
# 16131      Strategy       NaN        0        0     0.12           0

# %% [markdown]
# 그럼 Year, Genre, Publisher 의 값들은 뭐가 있는지 살펴보자

# %% [markdown]
# Year 의 경우 20xx / xx 등으로 값이 나누어져 있다. 20xx로 통일시키자

# %%
data.Year.value_counts()
# Out:
# 2009.0    1421
# 2008.0    1418
# 2010.0    1252
# 2007.0    1199
# 2011.0    1129
#           ...
# 13.0         2
# 97.0         2
# 94.0         1
# 2020.0       1
# 86.0         1
# Name: Year, Length: 62, dtype: int64

# %%
data.Genre.value_counts()
# Out:
# Action          3305
# Sports          2341
# Misc            1734
# Role-Playing    1483
# Shooter         1308
# Adventure       1280
# Racing          1243
# Platform         884
# Simulation       865
# Fighting         847
# Strategy         680
# Puzzle           578
# Name: Genre, dtype: int64

# %%
data.Publisher.value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Summitsoft                         1
# Answer Software                    1
# CPG Products                       1
# Enjoy Gaming ltd.                  1
# CCP                                1
# Name: Publisher, Length: 578, dtype: int64

# %% [markdown]
# 결측치 비율 그래프 - 이를 보고 버릴것인지 채울것인지를 정한다.
# missingno 패키지를 활용해서 null data 를 더 쉽게 볼 수 있다

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 결측치의 비율이 매우 낮아 보인다. 수치로는?

# %%
for column in data.columns:
    ratio = len(data.loc[data[column].isnull()])/len(data[column])
    print(f'{column} : {ratio*100:.4f}% of null data')
# Out:
# Name : 0.0000% of null data
# Platform : 0.0000% of null data
# Year : 1.6327% of null data
# Genre : 0.3012% of null data
# Publisher : 0.3494% of null data
# NA_Sales : 0.0000% of null data
# EU_Sales : 0.0000% of null data
# JP_Sales : 0.0000% of null data
# Other_Sales : 0.0000% of null data

# %% [markdown]
# year, Genre, Publisher 의 null 비율은 각각 1.6%, 0.3%, 0.35% 로 매우 낮음을 알수 있다. 그래서 해당 데이터는 그냥 제거를 할것이다.

# %%
# 결측치 제거
data1 = data.dropna()
data1
# Out:
#                                                  Name Platform    Year  \
# 1                        Candace Kane's Candy Factory       DS  2008.0
# 2                                      The Munchables      Wii  2009.0
# 3      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 4                    Deal or No Deal: Special Edition       DS  2010.0
# 5           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16594                         Ice Age 2: The Meltdown       GC  2006.0
# 16595                     Rainbow Islands: Revolution      PSP  2005.0
# 16596                                        NBA 2K16      PS3  2015.0
# 16597                     Toukiden: The Age of Demons      PSV  2013.0
# 16598                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher NA_Sales EU_Sales JP_Sales  \
# 1         Action                    Destineer     0.04        0        0
# 2         Action           Namco Bandai Games     0.17        0        0
# 3      Adventure                    Alchemist        0        0     0.02
# 4           Misc                    Zoo Games     0.04        0        0
# 5       Platform                  D3Publisher     0.12     0.09        0
# ...          ...                          ...      ...      ...      ...
# 16594   Platform                Vivendi Games     0.15     0.04        0
# 16595     Action            Rising Star Games     0.01        0        0
# 16596     Sports         Take-Two Interactive     0.44     0.19     0.03
# 16597     Action                   Tecmo Koei     0.05     0.05     0.25
# 16598   Fighting  Sony Computer Entertainment        0        0     0.16
#
#       Other_Sales
# 1               0
# 2            0.01
# 3               0
# 4               0
# 5            0.04
# ...           ...
# 16594        0.01
# 16595           0
# 16596        0.13
# 16597        0.03
# 16598        0.01
#
# [16241 rows x 9 columns]

# %% [markdown]
# ### Sales 단위 조정
# 1. 기본단위를 M으로 본다.
# 2. K 가 있는 것들은 1000으로 나눠주고 뒤에 M을 붙인다.

# %%
data1[data1.NA_Sales.str.contains('M')]
# Out:
#                                              Name Platform    Year     Genre  \
# 448                    Medal of Honor: Warfighter     X360  2012.0    Action
# 459                                       F1 2010      PS3  2010.0    Racing
# 578                                 Mario Kart 64      N64  1996.0    Racing
# 626                                    The Hobbit      GBA  2003.0  Platform
# 673    Star Wars The Clone Wars: Lightsaber Duels      Wii  2008.0    Action
# ...                                           ...      ...     ...       ...
# 15987                 Juiced 2: Hot Import Nights       PC  2007.0    Racing
# 16153                       Taiko no Tatsujin Wii      Wii  2008.0      Misc
# 16170                    Medal of Honor: Airborne     X360  2007.0   Shooter
# 16409               NASCAR 06: Total Team Control      PS2  2005.0    Racing
# 16483            Super Robot Taisen F Kanketsuhen      SAT    98.0  Strategy
#
#                 Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# 448       Electronic Arts    0.58M     0.47     0.01         0.1
# 459           Codemasters    0.25M     0.76     0.08        0.27
# 578              Nintendo    5.55M     1.94     2.23        0.15
# 626         Vivendi Games    0.14M     0.05        0           0
# 673             LucasArts    1.23M      0.3        0        0.14
# ...                   ...      ...      ...      ...         ...
# 15987                 THQ       0M     0.01        0           0
# 16153  Namco Bandai Games       0M        0     0.67           0
# 16170     Electronic Arts    0.45M     0.53     0.01        0.12
# 16409     Electronic Arts    0.53M     0.02        0        0.09
# 16483           Banpresto       0M        0     0.55           0
#
# [97 rows x 9 columns]

# %%
# Sales의 M, K 값들을 모두 통일시켜 숫자로 반환
def sales_convert(price):
    if price[-1] == 'M':
        return float(price[:-1])
    elif price[-1] == 'K':
        return float(price[:-1])/1000
    else:
        return float(price)

data2 = data1.copy()
data2.loc[:,'NA_Sales'] = data2.loc[:,'NA_Sales'].apply(sales_convert)
data2.loc[:,'EU_Sales'] = data2.loc[:,'EU_Sales'].apply(sales_convert)
data2.loc[:,'JP_Sales'] = data2.loc[:,'JP_Sales'].apply(sales_convert)
data2.loc[:,'Other_Sales'] = data2.loc[:,'Other_Sales'].apply(sales_convert)

data2
# Out:
#                                                  Name Platform    Year  \
# 1                        Candace Kane's Candy Factory       DS  2008.0
# 2                                      The Munchables      Wii  2009.0
# 3      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 4                    Deal or No Deal: Special Edition       DS  2010.0
# 5           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16594                         Ice Age 2: The Meltdown       GC  2006.0
# 16595                     Rainbow Islands: Revolution      PSP  2005.0
# 16596                                        NBA 2K16      PS3  2015.0
# 16597                     Toukiden: The Age of Demons      PSV  2013.0
# 16598                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1         Action                    Destineer      0.04      0.00      0.00
# 2         Action           Namco Bandai Games      0.17      0.00      0.00
# 3      Adventure                    Alchemist      0.00      0.00      0.02
# 4           Misc                    Zoo Games      0.04      0.00      0.00
# 5       Platform                  D3Publisher      0.12      0.09      0.00
# ...          ...                          ...       ...       ...       ...
# 16594   Platform                Vivendi Games      0.15      0.04      0.00
# 16595     Action            Rising Star Games      0.01      0.00      0.00
# 16596     Sports         Take-Two Interactive      0.44      0.19      0.03
# 16597     Action                   Tecmo Koei      0.05      0.05      0.25
# 16598   Fighting  Sony Computer Entertainment      0.00      0.00      0.16
#
#        Other_Sales
# 1             0.00
# 2             0.01
# 3             0.00
# 4             0.00
# 5             0.04
# ...            ...
# 16594         0.01
# 16595         0.00
# 16596         0.13
# 16597         0.03
# 16598         0.01
#
# [16241 rows x 9 columns]

# %%
data2.loc[[11,46,146,879],:]  #Sales 변환 여부 확인
# Out:
#                                                Name Platform    Year  \
# 11                                      Ford Racing       PS  2001.0
# 46                     Resident Evil: Revelations 2      PS3  2015.0
# 146                              TOCA Race Driver 3       PC  2006.0
# 879  Tears to Tiara Anecdotes: The Secret of Avalon      PS3  2009.0
#
#         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 11     Racing  Empire Interactive      0.48      0.33      0.00         0.06
# 46     Action              Capcom      0.06      0.08      0.16         0.03
# 146    Racing         Codemasters      0.00      0.02      0.00         0.00
# 879  Strategy           Aqua Plus      0.00      0.00      0.04         0.00

# %% [markdown]
# # Q1) 지역에 따라서 선호하는 게임 장르가 다른가?

# %% [markdown]
# 먼저 Genre별로 지역별 Sales 총합을 계산한다.

# %%
data2.groupby('Genre').sum()
# Out:
#                    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        6477917.0    858.75    513.64    156.60       183.99
# Adventure     2538404.0    101.79     63.66     51.87        16.70
# Fighting      1662060.0    220.35     99.90     87.14        36.15
# Misc          3354273.0    394.73    208.15    104.18        72.64
# Platform      1733521.0    445.38    200.63    130.53        51.45
# Puzzle        1118959.0    121.58     50.47     56.24        12.44
# Racing        2424102.0    354.70    235.02     56.32        76.51
# Role-Playing  2924339.0    318.76    183.09    342.93        56.73
# Shooter       2543679.0    574.48    310.23     38.18       101.86
# Simulation    1687540.0    181.43    112.99     63.54        31.32
# Sports        4590719.0    667.26    370.97    134.76       132.35
# Strategy      1331939.0     67.83     44.82     49.10        11.23

# %%
data2.groupby('Genre').sum().plot.bar(y=['NA_Sales','EU_Sales',
                                        'JP_Sales','Other_Sales'])
# Out:
# <AxesSubplot:xlabel='Genre'>

# %% [markdown]
# 절대량으로 보았을 때는 NA 쪽의 판매량이 높고, EU, JP, Other 순으로 판매량이 높다.
# 하지만 지역 내에서의 Genre별 선호도를 잘 보기 위해서는 각 지역별 총합으로 나누어주면 ratio를 볼 수 있다.

# %%
# ratio plot
data_gen = data2.groupby('Genre').sum().loc[:,['NA_Sales','EU_Sales',
                                              'JP_Sales','Other_Sales']]


for column in data_gen.columns:
    data_gen.loc[:,column] = data_gen.loc[:,column] / data_gen[column].sum()
data_gen.plot.bar(ylabel='ratio')
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='ratio'>

# %% [markdown]
# #### Q1) 지역에 따라서 선호하는 게임 장르가 다른가?
# ## A) NA, EU, Other 지역은 전체 장르에서 비율의 차이가 크게 나지 않는다. 하지만 JP의 경우, 다른 세 지역과 비교하여 큰 차이를 보이는데 가장 두드러진 특징으로는 Action, Racing, Shooter, Sports의 선호도가 타 지역과 비교하여 떨어지고 다른 부분에서 선호도가 높은데 특히 Adventure, Puzzle, Strategy, Role-Playing 장르의 선호도가 압도적으로 높다는 점이다.

# %% [markdown]
# ================================================

# %% [markdown]
# ## Q2) 연도별 게임의 트렌드가 있을까?

# %% [markdown]
# 게임의 트렌드를 보는 방향은 네 가지다 - **Platform / Genre / Publisher / Sales** 의 경향을 연도별로 살펴보는 것이다.
# Publisher 의 경우 너무 경우가 많고 트렌드를 파악하기에는 시간이 많이 걸리는 관계로, Platform / Genre / Sales 의 경향만 살펴보았다.

# %% [markdown]
# Year 의 형식 통일해야 함.
# 현재 Year 의 표기형식 :
# 1) 20xx, 19xx
#
# 2) 20, 19 가 빠진 그냥 xx -> 이 경우 뒤 년도에 맞춰 19, 20을 앞에 추가해야 함

# %% [markdown]
# 현재 년도 2021 을 기준으로하여 21보다 크면 19xx , 21보다 작으면 20xx으로 한다.
# 1921년도나 그 이전에 게임이 만들어지진 않았을 테니까.
# 실제로 21보다 큰 xx 형태는 90년대부터 시작하므로 19xx로 하는 게 맞다!

# %%
data2[(data2.Year < 1000) &
     (data2.Year > 21)].Year
# Out:
# 82       97.0
# 907      96.0
# 2430     96.0
# 3493     98.0
# 4366     86.0
# 4808     95.0
# 4840     95.0
# 10316    97.0
# 10706    96.0
# 11335    95.0
# 14573    98.0
# 14786    95.0
# 15986    94.0
# 16483    98.0
# Name: Year, dtype: float64

# %%
# year 데이터 xxxx형태로 변환하기
def year_convert(year):
    if year < 21:
        return year + 2000
    elif year < 100:
        return year + 1900
    else:
        return year
data3 = data2.copy()
data3.loc[:,'Year'] = data3.loc[:,'Year'].apply(year_convert)

# %%
# Platform 트렌드

sns.catplot(x = 'Year', y = 'Platform', data=data3, )
plt.title("Count platform of every game by year")
# Out:
# Text(0.5, 1.0, 'Count platform of every game by year')

# %%
# Genre 트렌드
sns.catplot(x = 'Year', y = 'Genre', data=data3)
plt.title("Count Genre of every game by year")
# Out:
# Text(0.5, 1.0, 'Count Genre of every game by year')

# %% [markdown]
# ### 전체 Sales 총합 생성

# %% [markdown]
# sales 총합의 연도에 따른 장르별, 플랫폼별 비교

# %%
# 장르와 연도에 따른 sales 총합 생성
data3['Total_Sales'] = data3['NA_Sales'] + data3['EU_Sales'] + \
                        data3['JP_Sales'] + data3['Other_Sales']
pg = data3.pivot_table(index='Year', columns='Genre', values='Total_Sales',
                      aggfunc='sum')
pg = pg.reset_index() #index 생성하여 year을 컬럼으로 오게 함
pg
# Out:
# Genre    Year  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# 0      1980.0    0.34        NaN      0.77   2.70       NaN     NaN     NaN
# 1      1981.0   14.79        NaN       NaN    NaN      6.92    2.25    0.48
# 2      1982.0    6.50        NaN       NaN   0.87      5.03   10.04    1.57
# 3      1983.0    2.86       0.40       NaN   2.14      6.93    0.78     NaN
# 4      1984.0    1.85        NaN       NaN   1.45      0.69    3.14    5.95
# 5      1985.0    3.52        NaN      1.05    NaN     43.17    3.21     NaN
# 6      1986.0   13.74        NaN       NaN    NaN      9.39     NaN    1.96
# 7      1987.0    1.11       4.38      5.42    NaN      1.74     NaN     NaN
# 8      1988.0    1.74        NaN       NaN    NaN     27.73    5.58    2.14
# 9      1989.0    4.65        NaN       NaN   1.28     20.66   37.75     NaN
# 10     1990.0    6.39        NaN       NaN    NaN     22.98    5.99    6.25
# 11     1991.0    6.76       2.24      0.39   0.08      7.63    3.24    1.14
# 12     1992.0    3.84      12.24     15.23   4.94     13.41    4.84    9.05
# 13     1993.0    1.81       0.07      8.75   0.30     18.68    3.17    0.36
# 14     1994.0    1.55       3.74      8.47   2.86     28.76    1.53    2.18
# 15     1995.0    3.58       0.71     14.84   6.39     16.69    2.69    6.09
# 16     1996.0   20.60       4.18     18.04  10.66     28.23    3.92   27.85
# 17     1997.0   27.59       4.97     11.80   5.68     21.86    5.87   31.92
# 18     1998.0   39.41       9.04     31.68  11.84     29.83    6.35   26.78
# 19     1999.0   27.62       7.61     14.31  20.68     20.80    1.34   37.19
# 20     2000.0   33.89       2.96     20.26  15.55     16.05    3.83   20.00
# 21     2001.0   56.68       8.96     18.10  16.39     39.33    7.94   55.83
# 22     2002.0   86.65      11.07     24.92  15.63     45.95    5.33   30.15
# 23     2003.0   67.98       2.12     23.79  23.79     42.82    1.71   52.18
# 24     2004.0   76.15       8.45     16.76  26.10     47.34    8.41   45.61
# 25     2005.0   85.52       8.53     19.68  59.69     22.81   20.26   56.40
# 26     2006.0   66.49      11.48     22.53  67.23     49.70   10.79   34.06
# 27     2007.0  105.99      24.44     17.63  91.07     35.53   23.78   38.95
# 28     2008.0  135.46      24.91     35.41  86.18     35.65   15.53   70.73
# 29     2009.0  138.32      20.67     32.18  76.90     40.95   20.28   34.09
# 30     2010.0  117.50      16.57     14.88  88.40     31.98   11.15   34.93
# 31     2011.0  119.00      15.88     22.11  55.77     28.12    5.10   34.96
# 32     2012.0  120.78       5.90      9.53  22.93     18.54    1.74   14.43
# 33     2013.0  125.21       6.61      7.23  25.66     25.09    1.00   13.02
# 34     2014.0   99.01       6.09     16.15  23.73      8.87    1.50   16.71
# 35     2015.0   68.25       8.01      7.78  11.66      6.05    0.69    7.92
# 36     2016.0   19.84       1.79      3.85   1.15      2.08     NaN    1.67
# 37     2017.0    0.01        NaN       NaN    NaN       NaN     NaN     NaN
# 38     2020.0     NaN        NaN       NaN    NaN       NaN     NaN     NaN
#
# Genre  Role-Playing  Shooter  Simulation  Sports  Strategy
# 0               NaN     7.07         NaN     NaN       NaN
# 1               NaN    10.02        0.44    0.78       NaN
# 2               NaN     3.81         NaN    1.06       NaN
# 3               NaN     0.49         NaN    3.20       NaN
# 4               NaN    31.10         NaN    6.17       NaN
# 5               NaN     1.00        0.04    1.96       NaN
# 6              2.52     3.89         NaN    5.58       NaN
# 7              4.65     0.69         NaN    3.71       NaN
# 8              5.88     0.51        0.03    3.60       NaN
# 9              2.20     1.19         NaN    5.72       NaN
# 10             4.52      NaN        1.13    2.11       NaN
# 11             3.26     1.99        2.15    2.41      0.94
# 12             6.86     0.28        2.14    2.95      0.36
# 13             5.59     3.08        0.19    3.18      0.81
# 14             7.13     8.30        2.72    8.41      3.57
# 15            14.27     4.15        4.17    7.99      6.54
# 16            43.99     6.90       11.33   17.42      5.61
# 17            21.82    22.16        9.64   30.04      7.72
# 18            28.09     9.80        7.11   41.75     13.49
# 19            47.24    12.23       11.46   30.21     18.47
# 20            29.04     6.83        3.37   41.24      8.52
# 21            22.02    24.81       19.54   51.47      7.54
# 22            45.09    47.64       10.82   65.31      5.51
# 23            30.29    27.10       21.21   55.96      7.95
# 24            53.95    46.92       10.89   61.11      7.14
# 25            28.51    41.57       49.28   59.53      5.34
# 26            51.79    38.35       21.73  136.12      4.23
# 27            43.86    70.88       48.85   98.24      9.38
# 28            59.69    59.51       46.40   95.24     11.70
# 29            47.96    69.84       33.55  138.59     12.51
# 30            70.56    77.44       21.90   92.02     13.82
# 31            53.32    99.35       15.31   57.06      8.87
# 32            47.77    72.84       13.37   30.90      3.33
# 33            30.54    62.73        8.68   41.54      6.32
# 34            45.88    65.99        5.54   46.64      0.97
# 35            36.43    66.12        5.61   41.49      1.82
# 36             6.75    18.17        0.39   14.63      0.52
# 37             0.04      NaN         NaN     NaN       NaN
# 38              NaN      NaN        0.29     NaN       NaN

# %%
pgm = pg.melt(id_vars=['Year']).sort_values('Year')
pgm
# Out:
#        Year      Genre  value
# 0    1980.0     Action   0.34
# 429  1980.0   Strategy    NaN
# 78   1980.0   Fighting   0.77
# 117  1980.0       Misc   2.70
# 390  1980.0     Sports    NaN
# ..      ...        ...    ...
# 116  2020.0   Fighting    NaN
# 77   2020.0  Adventure    NaN
# 38   2020.0     Action    NaN
# 428  2020.0     Sports    NaN
# 467  2020.0   Strategy    NaN
#
# [468 rows x 3 columns]

# %% [markdown]
# ### 연도에 따른 장르별 판매량 비교

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=pgm,x='Year',y='Genre',size='value',
               sizes=(0,400))
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Genre'>

# %% [markdown]
# ### 연도에 따른 플랫폼별 판매량 비교

# %%
pgpl = data3.pivot_table(index='Year', columns='Platform', values='Total_Sales',
                      aggfunc='sum')
pgpl = pgpl.reset_index() #index 생성하여 year을 컬럼으로 오게 함

pgpl_m = pgpl.melt(id_vars=['Year']).sort_values('Year')


fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=pgpl_m,x='Year',y='Platform',size='value',
               sizes=(0,400))
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Platform'>

# %% [markdown]
# ### 연도별 각 지역의 Sales의 트렌드

# %%
data_year = data3.groupby('Year').sum()

fig, ax = plt.subplots(figsize=(8,6))
data_year.plot(y=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],
              ax=ax)
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# #### Q2) 연도별 게임의 트렌드가 있을까?
# ## A) 연도별로 Genre, Platform, 지역별 판매량 의 추세의 차이를 확인해 보았을때, Genre는 상대적으로 트렌드의 큰 변화는 없었으나 Game 을 플레이하는 Platform 이 시대가 지날수록 점점 새로운 게임기로 옮겨가는 것이 확연히 보여졌다.
# ## 지역별 판매량은 모두 1995년부터 2009년 쯤 까지 모든 지역에서 증가하다가 감소하였다. 판매량 증감의 경향은 JP를 제외한 모든 지역이 비슷한 양상을 보였다.

# %% [markdown]
# ================================

# %% [markdown]
# ## Q3) 출고량이 높은 게임에 대한 분석 및 시각화

# %%
# 게임별 출고량 비교하기
data3[data3.Total_Sales<40].Total_Sales.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 출고량 x 값을 log 를 취한다
data3['Total_Sales_log'] = data3.Total_Sales.apply(lambda x:np.log(x) if x > 0 else 0)
data3.Total_Sales_log
# Out:
# 1       -3.218876
# 2       -1.714798
# 3       -3.912023
# 4       -3.218876
# 5       -1.386294
#            ...
# 16594   -1.609438
# 16595   -4.605170
# 16596   -0.235722
# 16597   -0.967584
# 16598   -1.771957
# Name: Total_Sales_log, Length: 16241, dtype: float64

# %%
data3.Total_Sales_log.plot.hist()
plt.xlabel('10^x')
plt.axvline(0,color='r')

# %% [markdown]
# #### Total_Sales_log > 0, 즉 1M 이상의 판매고를 올린 것들을 높은 판매량의 게임이라 하자.

# %%
lot = data3[data3.Total_Sales>1]
lot
# Out:
#                                                 Name Platform    Year  \
# 21                            Ty the Tasmanian Tiger      PS2  2002.0
# 25                          Injustice: Gods Among Us      PS3  2013.0
# 60                                         Bomberman      NES  1985.0
# 67                                Kirby: Mass Attack       DS  2011.0
# 93                                   Disney Universe      Wii  2011.0
# ...                                              ...      ...     ...
# 16564                                         Wall-E      Wii  2008.0
# 16574                                   Finding Nemo      PS2  2003.0
# 16576                             Grand Theft Auto V       PC  2015.0
# 16584  LEGO Indiana Jones 2: The Adventure Continues      Wii  2009.0
# 16592                                Madden NFL 2005      PS2  2004.0
#
#           Genre                               Publisher  NA_Sales  EU_Sales  \
# 21     Platform                         Electronic Arts      0.57      0.45
# 25     Fighting  Warner Bros. Interactive Entertainment      0.48      0.53
# 60       Puzzle                             Hudson Soft      0.18      0.00
# 67     Platform                                Nintendo      0.52      0.06
# 93       Action              Disney Interactive Studios      0.67      0.30
# ...         ...                                     ...       ...       ...
# 16564  Platform                                     THQ      0.51      0.40
# 16574    Action                                     THQ      1.26      0.60
# 16576    Action                    Take-Two Interactive      0.36      0.64
# 16584    Action                              Activision      0.91      0.39
# 16592    Sports                         Electronic Arts      4.18      0.26
#
#        JP_Sales  Other_Sales  Total_Sales  Total_Sales_log
# 21         0.00         0.15         1.17         0.157004
# 25         0.01         0.23         1.25         0.223144
# 60         0.85         0.00         1.03         0.029559
# 67         0.41         0.05         1.04         0.039221
# 93         0.00         0.10         1.07         0.067659
# ...         ...          ...          ...              ...
# 16564      0.00         0.11         1.02         0.019803
# 16574      0.05         0.18         2.09         0.737164
# 16576      0.00         0.08         1.08         0.076961
# 16584      0.00         0.13         1.43         0.357674
# 16592      0.01         0.08         4.53         1.510722
#
# [2021 rows x 11 columns]

# %% [markdown]
# 분석 및 시각화 방법들
#
# 1) 년도
# 2) 지역별 판매량
# 3) 게임 회사
# 4) 플랫폼
#
# 판매량 적은 데이터와 비교해보자.

# %%
less = data3[data3.Total_Sales <= 1]
less
# Out:
#                                                  Name Platform    Year  \
# 1                        Candace Kane's Candy Factory       DS  2008.0
# 2                                      The Munchables      Wii  2009.0
# 3      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 4                    Deal or No Deal: Special Edition       DS  2010.0
# 5           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16594                         Ice Age 2: The Meltdown       GC  2006.0
# 16595                     Rainbow Islands: Revolution      PSP  2005.0
# 16596                                        NBA 2K16      PS3  2015.0
# 16597                     Toukiden: The Age of Demons      PSV  2013.0
# 16598                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1         Action                    Destineer      0.04      0.00      0.00
# 2         Action           Namco Bandai Games      0.17      0.00      0.00
# 3      Adventure                    Alchemist      0.00      0.00      0.02
# 4           Misc                    Zoo Games      0.04      0.00      0.00
# 5       Platform                  D3Publisher      0.12      0.09      0.00
# ...          ...                          ...       ...       ...       ...
# 16594   Platform                Vivendi Games      0.15      0.04      0.00
# 16595     Action            Rising Star Games      0.01      0.00      0.00
# 16596     Sports         Take-Two Interactive      0.44      0.19      0.03
# 16597     Action                   Tecmo Koei      0.05      0.05      0.25
# 16598   Fighting  Sony Computer Entertainment      0.00      0.00      0.16
#
#        Other_Sales  Total_Sales  Total_Sales_log
# 1             0.00         0.04        -3.218876
# 2             0.01         0.18        -1.714798
# 3             0.00         0.02        -3.912023
# 4             0.00         0.04        -3.218876
# 5             0.04         0.25        -1.386294
# ...            ...          ...              ...
# 16594         0.01         0.20        -1.609438
# 16595         0.00         0.01        -4.605170
# 16596         0.13         0.79        -0.235722
# 16597         0.03         0.38        -0.967584
# 16598         0.01         0.17        -1.771957
#
# [14220 rows x 11 columns]

# %% [markdown]
# 판매량 적은 / 많은 게임을 lot? 이름으로 라벨링

# %%
data3.loc[data3.Total_Sales>1,'lot?'] = 1
data3.loc[data3.Total_Sales<=1,'lot?'] = 0

data3
# Out:
#                                                  Name Platform    Year  \
# 1                        Candace Kane's Candy Factory       DS  2008.0
# 2                                      The Munchables      Wii  2009.0
# 3      Otome wa Oanesama Boku ni Koi Shiteru Portable      PSP  2010.0
# 4                    Deal or No Deal: Special Edition       DS  2010.0
# 5           Ben 10 Ultimate Alien: Cosmic Destruction      PS3  2010.0
# ...                                               ...      ...     ...
# 16594                         Ice Age 2: The Meltdown       GC  2006.0
# 16595                     Rainbow Islands: Revolution      PSP  2005.0
# 16596                                        NBA 2K16      PS3  2015.0
# 16597                     Toukiden: The Age of Demons      PSV  2013.0
# 16598                        The King of Fighters '95       PS  1996.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1         Action                    Destineer      0.04      0.00      0.00
# 2         Action           Namco Bandai Games      0.17      0.00      0.00
# 3      Adventure                    Alchemist      0.00      0.00      0.02
# 4           Misc                    Zoo Games      0.04      0.00      0.00
# 5       Platform                  D3Publisher      0.12      0.09      0.00
# ...          ...                          ...       ...       ...       ...
# 16594   Platform                Vivendi Games      0.15      0.04      0.00
# 16595     Action            Rising Star Games      0.01      0.00      0.00
# 16596     Sports         Take-Two Interactive      0.44      0.19      0.03
# 16597     Action                   Tecmo Koei      0.05      0.05      0.25
# 16598   Fighting  Sony Computer Entertainment      0.00      0.00      0.16
#
#        Other_Sales  Total_Sales  Total_Sales_log  lot?
# 1             0.00         0.04        -3.218876   0.0
# 2             0.01         0.18        -1.714798   0.0
# 3             0.00         0.02        -3.912023   0.0
# 4             0.00         0.04        -3.218876   0.0
# 5             0.04         0.25        -1.386294   0.0
# ...            ...          ...              ...   ...
# 16594         0.01         0.20        -1.609438   0.0
# 16595         0.00         0.01        -4.605170   0.0
# 16596         0.13         0.79        -0.235722   0.0
# 16597         0.03         0.38        -0.967584   0.0
# 16598         0.01         0.17        -1.771957   0.0
#
# [16241 rows x 12 columns]

# %%
lot_pg = data3[data3['lot?'] == 1].pivot_table(index='Year', columns=['Genre'], values='Total_Sales',
                      aggfunc='sum')
lot_pg = lot_pg.reset_index() #index 생성하여 year을 컬럼으로 오게 함

lot_m = lot_pg.melt(id_vars=['Year']).sort_values('Year')
lot_m = lot_m.sort_values('Genre')
lot_m
# Out:
#        Year     Genre  value
# 0    1980.0    Action    NaN
# 2    1982.0    Action    NaN
# 3    1983.0    Action    NaN
# 20   2000.0    Action  23.55
# 19   1999.0    Action  16.96
# ..      ...       ...    ...
# 417  1990.0  Strategy    NaN
# 416  1989.0  Strategy    NaN
# 415  1988.0  Strategy    NaN
# 438  2011.0  Strategy   4.18
# 443  2016.0  Strategy    NaN
#
# [444 rows x 3 columns]

# %% [markdown]
# ### 판매량 > 1M 게임의 연도/장르별 판매량

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=lot_m,x='Year',y='Genre',size='value',
               sizes=(50,400),ax=ax,alpha=1,c=['orange'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Genre'>

# %% [markdown]
# ### 판매량 <= 1M 게임의 연도/장르별 판매량

# %%
less_pg = data3[data3['lot?'] == 0].pivot_table(index='Year', columns=['Genre'], values='Total_Sales',
                      aggfunc='sum')
less_pg = less_pg.reset_index() #index 생성하여 year을 컬럼으로 오게 함

less_m = less_pg.melt(id_vars=['Year']).sort_values('Year')
less_m = less_m.sort_values('Genre')

fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(data=less_m,x='Year',y='Genre',size='value',
               sizes=(50,400),ax=ax,alpha=1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Genre'>

# %%
fig, ax = plt.subplots(1,2,figsize=(15,10))
sns.scatterplot(data=lot_m,x='Year',y='Genre',size='value',
               sizes=(50,400),ax=ax[0],alpha=1,c=['orange'])

sns.scatterplot(data=less_m,x='Year',y='Genre',size='value',
               sizes=(50,400),ax=ax[1],alpha=1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Genre'>

# %% [markdown]
# ### 판매량 높은 / 낮은 데이터의 장르별 트렌드 차이가 확연하게 드러나진 않는다.
# ### 차이점 : 최근 들어서 Shooter 게임이 판매량이 많은 것을 알 수 있다.

# %%
# 지역별 판매량
sales_lot = data3.loc[data3['lot?'] == 1,['Year','NA_Sales','EU_Sales','JP_Sales']].groupby('Year').sum()
sales_less = data3.loc[data3['lot?'] == 0,['Year','NA_Sales','EU_Sales','JP_Sales']].groupby('Year').sum()

fig, ax = plt.subplots(2,1,figsize=(8,6))
# lot_year = data3.groupby('Year').sum()
# lot_year = lot_year.sort_index('Year')
sales_lot.plot(y=['NA_Sales','EU_Sales','JP_Sales'],
              ax=ax[0])
sales_less.plot(y=['NA_Sales','EU_Sales','JP_Sales'],
              ax=ax[1])
ax[0].set_xlim(1978,2022)
ax[1].set_xlim(1978,2022)
ax[0].set_ylabel('Millions of sales')
ax[0].set_title('Games over 1 Million sales')
ax[1].set_title('Games less 1 Million sales')
plt.tight_layout()

# %% [markdown]
# ### MultiIndex 를 이용한 FacetGrid Plot - 판매량 많은 / 적은 데이터를 나누어 연도/장르에 따른 판매량을 시각화

# %%
# sum of sales by year , but divided to lot/less
data_lotd = data3.loc[:,['Year','Genre','Total_Sales','lot?']].melt(id_vars=['Year','Genre','Total_Sales'])
data_lotd[data_lotd['value'] == 0].groupby('Year').sum()

data_lotd_div = pd.concat([data_lotd[data_lotd['value'] == 0].groupby(['Year','Genre']).sum(),
                         data_lotd[data_lotd['value'] == 1].groupby(['Year','Genre']).sum()])

#make value to 1
data_lotd_div.loc[data_lotd_div.value != 0,'value'] = 1
data_lotd_div
# Out:
#                      Total_Sales  value
# Year   Genre
# 1980.0 Action               0.34    0.0
#        Fighting             0.77    0.0
#        Misc                 0.50    0.0
# 1981.0 Action              10.62    0.0
#        Platform             0.96    0.0
# ...                          ...    ...
# 2016.0 Fighting             1.06    1.0
#        Platform             1.18    1.0
#        Role-Playing         1.56    1.0
#        Shooter             12.92    1.0
#        Sports               8.73    1.0
#
# [678 rows x 2 columns]

# %%
# kdeplot
# %matplotlib inline
# plt.subplots(figsize=(8,6))
sns.relplot(data=data_lotd_div,x='Year',y='Total_Sales',kind='line',
           col='Genre',col_wrap=4,hue='value')

# %% [markdown]
# #### Q3) 출고량이 높은 게임에 대한 분석 및 시각화
# ## A) 총합 1백만 장 이상의 판매고를 올린 게임들을 따로 그룹을 나누어서 지역별 판매량을 비교하여 보았고, 또한 장르별로 나누어 연도별 판매량의 특성을 살펴보았다.
#
# ## 출고량 높은 게임과 낮은 게임의 연도별 트렌드는 큰 차이가 없었다.
# ## 출고량 높은 게임과 낮은 게임의 장르별 트렌드는 어느 정도 차이를 보인다.

# %% [markdown]
# ===========================================

# %% [markdown]
# ### 프로젝트 주제 : 다음 분기에 어떤 게임을 설계해야 할까?
# ### 결론: Q1) Q2) Q3) 의 결과를 바탕으로,
#
# 1) NA, EU, Other 지역은 전체 장르에서 비율의 차이가 크게 나지 않는다. 하지만 JP의 경우, 다른 세 지역과 비교하여 큰 차이를 보이는데 가장 두드러진 특징으로는 Action, Racing, Shooter, Sports의 선호도가 타 지역과 비교하여 떨어지고 다른 부분에서 선호도가 높은데 특히 Adventure, Puzzle, Strategy, Role-Playing 장르의 선호도가 압도적으로 높다는 점이다. 따라서 판매하고자 하는 지역에 따른 장르 선호도가 중요하다
#
# 2) PSP, PS3, PS4 등 최신 플랫폼 게임들이 선호된다. 하지만 PC 는 이전부터 지금까지 꾸준한 판매고를 유지하고 있으므로, 이러한 점을 고려하여 게임을 판매고가 높은 플랫폼에 맞추어 설계하는 것이 필요하다. 그리고 2015년 이후로 계속 판매량이 낮아지고 있어서 너무 큰 판매량은 기대하지 않는 것이 좋다.
#
# 3) 최근 판매고가 높은 게임의 장르는 Action , Shooter 게임이다. 따라서 이 두 가지의 장르 혹은 최근 판매고가 양호한 게임의 장르에 맞춰 개발하는 것이 좋을 것이다.
#
#
# ### 한계점: 발표 시간의 부족 및 데이터 분석 능력이 아직 부족하여 t-test, chi-square 및 기타 머신러닝 분석들을 적용해 보지 못하였다. 다음 기회에는 좀더 깊은 수준의 분석 방법을 적용하고 싶다.
# ####

# %% [markdown]
# ### https://brownbears.tistory.com/421 문자열 포맷팅 방법 정리 - 블로그에 정리하기
